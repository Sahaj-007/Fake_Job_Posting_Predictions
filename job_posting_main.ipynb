# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/fake_job_postings.csv.zip")
print(df)
# Out:
#        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# ...

# %%
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
df.tail()
# Out:
#        job_id                                              title  \
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 17875       CA, ON, Toronto        Sales          NaN
# 17876  US, PA, Philadelphia   Accounting          NaN
# 17877       US, TX, Houston          NaN          NaN
# 17878         NG, LA, Lagos          NaN          NaN
# 17879     NZ, N, Wellington  Engineering          NaN
#
#                                          company_profile  \
# 17875  Vend is looking for some awesome new talent to...
# 17876  WebLinc is the e-commerce platform and service...
# 17877  We Provide Full Time Permanent Positions for m...
# ...

# %%
df.shape
# Out:
# (17880, 18)

# %%
df.describe()
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count  17880.000000   17880.000000      17880.000000   17880.000000
# mean    8940.500000       0.042897          0.795302       0.491723
# std     5161.655742       0.202631          0.403492       0.499945
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.750000       0.000000          1.000000       0.000000
# 50%     8940.500000       0.000000          1.000000       0.000000
# 75%    13410.250000       0.000000          1.000000       1.000000
# max    17880.000000       1.000000          1.000000       1.000000
#
#          fraudulent
# count  17880.000000
# mean       0.048434
# std        0.214688
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15184 non-null  object
#  8   benefits             10668 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
df.drop('has_company_logo',axis=1,inplace=True)

# %%
df.drop('has_questions',axis=1,inplace=True)

# %%
df.drop('employment_type',axis=1,inplace=True)

# %%
df.drop('required_experience',axis=1,inplace=True)

# %%
df.drop('required_education',axis=1,inplace=True)

# %%
df.drop('industry',axis=1,inplace=True)

# %%
df.drop('function',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# job_id                 0
# title                  0
# location             346
# department         11547
# salary_range       15012
# company_profile     3308
# description            1
# requirements        2696
# benefits            7212
# telecommuting          0
# fraudulent             0
# dtype: int64

# %%
#Fill NULL values in string columns

string_cols = df.select_dtypes(include='object').columns  #object=text/string colns    #.columns--return only coln names

for col in string_cols:                             #Loop one by one through all text columns
    df[col] = df[col].fillna("Not Provided")        #Replacing NaN values

#  Fill Null values in numeric columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns   #int64=whole no's     #float64=decimal no's

for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())

print("Null values fixed successfully!")
print(df.isnull().sum())
# Out:
# Null values fixed successfully!
# job_id             0
# title              0
# location           0
# department         0
# salary_range       0
# company_profile    0
# description        0
# requirements       0
# benefits           0
# telecommuting      0
# fraudulent         0
# dtype: int64

# %% [markdown]
# TEXT CLEANING

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#define a texxt processing fun
def clean_text(text):
  text=re.sub(r'[^\w\s]', '', text)
  text=text.lower()
  text=word_tokenize(text)
  text=[word for word in text if word not in stopwords.words('english')]
  return ' '.join(text)

# %%
#Apply Preprocessing
df['clean_description'] = df['description'].apply(clean_text)

# %%
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#      department  salary_range  \
# 0     Marketing  Not Provided
# 1       Success  Not Provided
# 2  Not Provided  Not Provided
# 3         Sales  Not Provided
# 4  Not Provided  Not Provided
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
# ...

# %%
df.tail()
# Out:
#        job_id                                              title  \
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location    department  salary_range  \
# 17875       CA, ON, Toronto         Sales  Not Provided
# 17876  US, PA, Philadelphia    Accounting  Not Provided
# 17877       US, TX, Houston  Not Provided  Not Provided
# 17878         NG, LA, Lagos  Not Provided  Not Provided
# 17879     NZ, N, Wellington   Engineering  Not Provided
#
#                                          company_profile  \
# 17875  Vend is looking for some awesome new talent to...
# 17876  WebLinc is the e-commerce platform and service...
# 17877  We Provide Full Time Permanent Positions for m...
# ...

# %% [markdown]
# Basic EDA:Coorealtion Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Distribution of Real vs Fake Job Postings

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df,x='fraudulent',palette='viridis')
plt.title("Distribution of Real vs Fake Job Postings")
plt.xlabel("fraudulent")
plt.ylabel("frequency")
plt.show()
plt.xticks([0,1], ['No', 'Yes'])
# Out:
# /tmp/ipykernel_7717/2091312180.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='fraudulent',palette='viridis')
# ([<matplotlib.axis.XTick at 0x7ad89969c080>,
# ...
#  [Text(0, 0, 'No'), Text(1, 0, 'Yes')])

# %% [markdown]
# Telecommuting Distribution

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='telecommuting', palette='magma')

plt.title("Distribution of Telecommuting Jobs")
plt.xlabel("Telecommuting")
plt.ylabel("Frequency")
plt.xticks([0,1], ['No', 'Yes'])

plt.show()
# Out:
# /tmp/ipykernel_7717/1587568855.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='telecommuting', palette='magma')

# %% [markdown]
# Fake Jobs by Telecommuting

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='telecommuting', hue='fraudulent', palette='coolwarm')

plt.title("Fake Job Detection based on Telecommuting")
plt.xlabel("Telecommuting")
plt.ylabel("Count")
plt.xticks([0,1], ['No', 'Yes'])

plt.legend(title="Fraudulent", labels=['Real','Fake'])

plt.show()

# %% [markdown]
# Distribution of Job Description Length

# %%
df['desc_length'] = df['description'].astype(str).apply(len)  #len=23

plt.figure(figsize=(10,6))
sns.histplot(data=df, x='desc_length', bins=40, kde=True, color='teal')

# x=Uses desc len, bins=Divide into 40 groups,kde=Smooth density curve

plt.title("Distribution of Job Description Length")
plt.xlabel("Description Length")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# PIE CHART

# %%
# Count values
counts = df['fraudulent'].value_counts()

# Pie Chart
plt.figure(figsize=(8,6))

plt.pie(counts,labels=['Real Jobs', 'Fake Jobs'],autopct='%1.1f%%',startangle=90,colors=['skyblue','salmon'],explode=(0,0.1))

plt.title("Percentage of Real vs Fake Job Postings")
plt.show()

# %% [markdown]
# Correlation matrix
#
# telecommuting--Remote job or not (0/1)
#
#
# desc_length----Length of job description
#
#
# fraudulent----Fake job or real (0/1)

# %%
numeric_df = df[['telecommuting','desc_length','fraudulent']]

plt.figure(figsize=(6,4))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
#sns.heatmap--Converts correlation table into colored chart
#annot=Shows numbers inside boxes.
plt.title("Correlation Matrix")
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Combine useful text columns
df['text_data'] = df['title'] + " " + df['description'] + " " + df['requirements']
# generally fake clues exist in this 3

# Convert text to TF-IDF features
tfidf = TfidfVectorizer(max_features=5000)

X = tfidf.fit_transform(df['text_data']).toarray()

# Target column
y = df['fraudulent']

# %% [markdown]
# TRAIN-TEST SPLIT

# %%
# Splitting the data for Fake Job Posting Project
# Taking input features (x)
x = np.array(df[['telecommuting', 'desc_length']])

# Taking target output (y) which we have to predict
y = np.array(df['fraudulent'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.20, random_state=42)

# %% [markdown]
# TRAINING A MODEL

# %% [markdown]
# 1.Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_model=LogisticRegression()
lr_model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#Logistic Regression
lr_preds=lr_model.predict(x_test)
print("Logistic Regression")
print("Accuracy:", accuracy_score(y_test,lr_preds))
# Out:
# Logistic Regression
# Accuracy: 0.9493847874720358

# %% [markdown]
# 2.Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

nb_model=MultinomialNB()
nb_model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
#Naive Bayes
nb_preds=nb_model.predict(x_test)
print("\nNaive Bayes")
print("Acurracy:", accuracy_score(y_test,nb_preds))
# Out:
# Naive Bayes
# Acurracy: 0.9493847874720358

# %% [markdown]
# 3.SVM

# %%
from sklearn.svm import SVC

svm_model=SVC()
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
#Support Vector Machine
svm_preds=svm_model.predict(x_test)
print("\nSupport vector machine")
print("Acurracy:", accuracy_score(y_test,svm_preds))
# Out:
# Support vector machine
# Acurracy: 0.9493847874720358

# %% [markdown]
# 4.Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model=RandomForestClassifier()
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_preds=rf_model.predict(x_test)
print("\nRandom forest")
print("Acurracy:",accuracy_score(y_test,rf_preds))
# Out:
# Random forest
# Acurracy: 0.9474272930648769

# %% [markdown]
# CONFUSION MATRIX---A confusion matrix shows what types of mistakes the model makes.
#
# 0=Real job
#
#
# 1=Fake job

# %%
y_preds = rf_model.predict(x_test)

# Now use it in evaluation
from sklearn.metrics import confusion_matrix, accuracy_score

print("Accuracy:", accuracy_score(y_test, y_preds))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_preds))
# Out:
# Accuracy: 0.9474272930648769
# Confusion Matrix:
# [[3341   54]
#  [ 134   47]]

# %% [markdown]
# MODEL EVALUATION MATRIX--model evaluation metrics that measure how well the model predicts fraudulent (1) vs real (0) jobs.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import f1_score, confusion_matrix, classification_report

print("Accuracy :", accuracy_score(y_test, y_preds))   #measure overall correct predictions.
print("Precision:", precision_score(y_test, y_preds))  #Out of jobs predicted fake, how many were actually fake
print("Recall   :", recall_score(y_test, y_preds))     #Out of actual fake jobs, how many did model catch
print("F1 Score :", f1_score(y_test, y_preds))         #Balance of precision + recall.

print("\nConfusion Matrix")                            #Use to inspect false negatives
print(confusion_matrix(y_test, y_preds))


print("\nClassification Report")
print(classification_report(y_test, y_preds))

#Since fake job datasets are imbalanced, we used Recall and F1-score along with Accuracy to properly evaluate the classifier
# Out:
# Accuracy : 0.9474272930648769
# Precision: 0.46534653465346537
# Recall   : 0.2596685082872928
# F1 Score : 0.3333333333333333
#
# Confusion Matrix
# [[3341   54]
#  [ 134   47]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      3395
#            1       0.47      0.26      0.33       181
#
#     accuracy                           0.95      3576
#    macro avg       0.71      0.62      0.65      3576
# weighted avg       0.94      0.95      0.94      3576
